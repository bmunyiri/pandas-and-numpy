# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\Desktop\\weather.csv", delimiter=",")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   day     9 non-null      object
#  1   temp    7 non-null      float64
#  2   wind    7 non-null      float64
#  3   event   7 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 416.0+ bytes

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\Desktop\\weather.csv",parse_dates=["day"], delimiter=",")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   day     9 non-null      datetime64[ns]
#  1   temp    7 non-null      float64
#  2   wind    7 non-null      float64
#  3   event   7 non-null      object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 416.0+ bytes

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#             temp  wind  event
# day
# 2017-01-02  34.0   3.0   rain
# 2017-01-03  32.0   4.0  sunny
# 2017-01-04   NaN   5.0   rain
# 2017-01-05  33.0   NaN   snow
# 2017-01-06  23.0   8.0   snow
# 2017-01-07  43.0   7.0    NaN
# 2017-01-08   NaN   NaN    NaN
# 2017-01-09  23.0   4.0  sunny
# 2017-01-10  22.0   3.0   rain

# %%
#set index
df.set_index("day", inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 #set index
# ----> 2 df.set_index("day", inplace=True)
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
# ...

# %%
df
# Out:
#             temp  wind  event
# day
# 2017-01-02  34.0   3.0   rain
# 2017-01-03  32.0   4.0  sunny
# 2017-01-04   NaN   5.0   rain
# 2017-01-05  33.0   NaN   snow
# 2017-01-06  23.0   8.0   snow
# 2017-01-07  43.0   7.0    NaN
# 2017-01-08   NaN   NaN    NaN
# 2017-01-09  23.0   4.0  sunny
# 2017-01-10  22.0   3.0   rain

# %%
new1 = df.fillna(0)
new1
# Out:
#             temp  wind  event
# day
# 2017-01-02  34.0   3.0   rain
# 2017-01-03  32.0   4.0  sunny
# 2017-01-04   0.0   5.0   rain
# 2017-01-05  33.0   0.0   snow
# 2017-01-06  23.0   8.0   snow
# 2017-01-07  43.0   7.0      0
# 2017-01-08   0.0   0.0      0
# 2017-01-09  23.0   4.0  sunny
# 2017-01-10  22.0   3.0   rain

# %%
new2=df.fillna({
    "temp": 0,
    "wind":0,
    "event":"no event"
})
new2
# Out:
#             temp  wind     event
# day
# 2017-01-02  34.0   3.0      rain
# 2017-01-03  32.0   4.0     sunny
# 2017-01-04   0.0   5.0      rain
# 2017-01-05  33.0   0.0      snow
# 2017-01-06  23.0   8.0      snow
# 2017-01-07  43.0   7.0  no event
# 2017-01-08   0.0   0.0  no event
# 2017-01-09  23.0   4.0     sunny
# 2017-01-10  22.0   3.0      rain

# %%
#Forward Fill
new3=df.fillna(method="ffill")
new3
# Out:
#             temp  wind  event
# day
# 2017-01-02  34.0   3.0   rain
# 2017-01-03  32.0   4.0  sunny
# 2017-01-04  32.0   5.0   rain
# 2017-01-05  33.0   5.0   snow
# 2017-01-06  23.0   8.0   snow
# 2017-01-07  43.0   7.0   snow
# 2017-01-08  43.0   7.0   snow
# 2017-01-09  23.0   4.0  sunny
# 2017-01-10  22.0   3.0   rain
