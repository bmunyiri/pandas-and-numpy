# %%
import pandas as pd
info = {'Name':["Tom",'Paul',"Jim"],'Age':['20','40','60']}
data =pd.DataFrame(info)
data['Total'] = data['Age'].sum()
print(data)
# Out:
#    Name Age   Total
# 0   Tom  20  204060
# 1  Paul  40  204060
# 2   Jim  60  204060

# %%
d = pd.read_excel('C:\\Users\\DELL\\Downloads\\car inventory.xlsx')

# %%
d.head(4)
# Out:
#        Car ID Make Make (Full Name) Model  Model (Full Name)  \
# 0  FD06MTG001   FD             Ford   NaN                NaN
# 1  FD06MTG002   FD             Ford   NaN                NaN
# 2  FD08MTG003   FD             Ford   NaN                NaN
# 3  FD08MTG004   FD             Ford   NaN                NaN
#
#    Manufacture Year  Age    Miles  Miles / Year  Color  Driver  \
# 0               NaN  NaN  40326.8           NaN  Black   Smith
# 1               NaN  NaN  44974.8           NaN  White  McCall
# 2               NaN  NaN  44946.5           NaN  Green    Lyon
# 3               NaN  NaN  37558.8           NaN  Black   Jones
#
#    Warantee Miles  Covered?  New Car ID
# 0         50000.0       NaN         NaN
# 1         50000.0       NaN         NaN
# 2         50000.0       NaN         NaN
# 3         50000.0       NaN         NaN

# %%
d.iloc[:5,[2,3]]
# Out:
#   Make (Full Name) Model
# 0             Ford   NaN
# 1             Ford   NaN
# 2             Ford   NaN
# 3             Ford   NaN
# 4             Ford   NaN

# %%
d.Miles.hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#         Car ID Make Make (Full Name)   Model Model (Full Name)  \
# 0   FD06MTG001   FD             Ford     MTG           Mustang
# 1   FD06MTG002   FD             Ford     MTG           Mustang
# 2   FD08MTG003   FD             Ford     MTG           Mustang
# 3   FD08MTG004   FD             Ford     MTG           Mustang
# 4   FD08MTG005   FD             Ford     MTG           Mustang
# ..         ...  ...              ...     ...               ...
# 60         NaN  NaN               TY  Toyota               ELA
# 61         NaN  NaN              NaN     NaN               FCS
# 62         NaN  NaN              NaN     NaN               MTG
# 63         NaN  NaN              NaN     NaN               ODY
# 64         NaN  NaN              NaN     NaN               PTC
#
#    Manufacture Year   Age    Miles  Miles / Year  Color  Driver  \
# 0                06  17.0  40326.8           NaN  Black   Smith
# 1                06  17.0  44974.8           NaN  White  McCall
# ...

# %%
df.columns
# Out:
# Index(['Car ID', 'Make', 'Make (Full Name)', 'Model', 'Model (Full Name)',
#        'Manufacture Year', 'Age', 'Miles', 'Miles / Year', 'Color', 'Driver',
#        'Warantee Miles', 'Covered?', 'New Car ID', 'Ca', 'r', 'ID',
#        'Unnamed: 17'],
#       dtype='object')

# %%
df[[ 'Make','Model']][0:10]
# Out:
#   Make Model
# 0   FD   MTG
# 1   FD   MTG
# 2   FD   MTG
# 3   FD   MTG
# 4   FD   MTG
# 5   FD   FCS
# 6   FD   FCS
# 7   FD   FCS
# 8   FD   FCS
# 9   FD   FCS

# %%
df.head(3)
# Out:
#        Car ID Make Make (Full Name) Model Model (Full Name) Manufacture Year  \
# 0  FD06MTG001   FD             Ford   MTG           Mustang               06
# 1  FD06MTG002   FD             Ford   MTG           Mustang               06
# 2  FD08MTG003   FD             Ford   MTG           Mustang               08
#
#     Age    Miles  Miles / Year  Color  Driver  Warantee Miles  Covered?  \
# 0  17.0  40326.8           NaN  Black   Smith         50000.0       NaN
# 1  17.0  44974.8           NaN  White  McCall         50000.0       NaN
# 2  15.0  44946.5           NaN  Green    Lyon         50000.0       NaN
#
#    New Car ID  Ca    r   ID  Unnamed: 17
# 0         NaN  FD  6.0  MTG          1.0
# 1         NaN  FD  6.0  MTG          2.0
# 2         NaN  FD  8.0  MTG          3.0

# %%
df.loc[df['Miles']>60000]
# Out:
#         Car ID Make Make (Full Name) Model Model (Full Name) Manufacture Year  \
# 17  GM98SLV018   GM   General Motors   SLV         PT Cruser               98
# 18  GM00SLV019   GM   General Motors   SLV         PT Cruser               00
# 19  TY96CAM020   TY           Toyota   CAM               NaN               96
# 20  TY98CAM021   TY           Toyota   CAM               NaN               98
# 21  TY00CAM022   TY           Toyota   CAM               NaN               00
# 22  TY02CAM023   TY           Toyota   CAM               NaN               02
# 24  TY02COR025   TY           Toyota   COR            Corola               02
# 25  TY03COR026   TY           Toyota   COR            Corola               03
# 29  HO99CIV030   HO            Honda   CIV             Civic               99
# 30  HO01CIV031   HO            Honda   CIV             Civic               01
# 36  HO05ODY037   HO            Honda   ODY            Odersy               05
# ...

# %%
df.loc[df['Ca']=='CR']
# Out:
#         Car ID Make Make (Full Name) Model Model (Full Name) Manufacture Year  \
# 41  CR04PTC042   CR        Chrystler   PTC         PT Cruser               04
# 42  CR07PTC043   CR        Chrystler   PTC         PT Cruser               07
# 43  CR11PTC044   CR        Chrystler   PTC         PT Cruser               11
# 44  CR99CAR045   CR        Chrystler   CAR            Carvan               99
# 45  CR00CAR046   CR        Chrystler   CAR            Carvan               00
# 46  CR04CAR047   CR        Chrystler   CAR            Carvan               04
# 47  CR04CAR048   CR        Chrystler   CAR            Carvan               04
#
#      Age    Miles  Miles / Year  Color    Driver  Warantee Miles  Covered?  \
# 41  19.0  64542.0           NaN   Blue     Smith         75000.0       NaN
# 42  16.0  42074.2           NaN  Green      Gaul         75000.0       NaN
# 43  12.0  27394.2           NaN  Black   Vizzini         75000.0       NaN
# ...

# %%
df.describe()
# Out:
#              Age          Miles  Miles / Year  Warantee Miles  Covered?  \
# count  52.000000      52.000000           0.0       52.000000       0.0
# mean   15.096154   44922.832692           NaN    84615.384615       NaN
# std     4.357817   25198.296539           NaN    16534.164091       NaN
# min     9.000000    3708.100000           NaN    50000.000000       NaN
# 25%    11.000000   24028.150000           NaN    75000.000000       NaN
# 50%    15.000000   38942.800000           NaN    75000.000000       NaN
# 75%    19.000000   65363.775000           NaN   100000.000000       NaN
# max    23.000000  114660.600000           NaN   100000.000000       NaN
#
#        New Car ID          r  Unnamed: 17
# count         0.0  52.000000    52.000000
# mean          NaN  16.942308    26.500000
# std           NaN  27.018812    15.154757
# min           NaN   0.000000     1.000000
# 25%           NaN   6.000000    13.750000
# 50%           NaN  10.000000    26.500000
# ...

# %%
df.head(3)
# Out:
#        Car ID Make Make (Full Name) Model Model (Full Name) Manufacture Year  \
# 0  FD06MTG001   FD             Ford   MTG           Mustang               06
# 1  FD06MTG002   FD             Ford   MTG           Mustang               06
# 2  FD08MTG003   FD             Ford   MTG           Mustang               08
#
#     Age    Miles  Miles / Year  Color  Driver  Warantee Miles  Covered?  \
# 0  17.0  40326.8           NaN  Black   Smith         50000.0       NaN
# 1  17.0  44974.8           NaN  White  McCall         50000.0       NaN
# 2  15.0  44946.5           NaN  Green    Lyon         50000.0       NaN
#
#    New Car ID  Ca    r   ID  Unnamed: 17
# 0         NaN  FD  6.0  MTG          1.0
# 1         NaN  FD  6.0  MTG          2.0
# 2         NaN  FD  8.0  MTG          3.0

# %%
df['Miles Per Year'] = df['Miles'] / df['Age']

# %%
print(df['Miles Per Year'].head(10))
# Out:
# 0    2372.164706
# 1    2645.576471
# 2    2996.433333
# 3    2503.920000
# 4    2429.233333
# 5    2724.200000
# 6    3072.323529
# 7    2509.785714
# 8    2763.710000
# 9    2753.480000
# Name: Miles Per Year, dtype: float64

# %%
df.head(3)
# Out:
#        Car ID Make Make (Full Name) Model Model (Full Name) Manufacture Year  \
# 0  FD06MTG001   FD             Ford   MTG           Mustang               06
# 1  FD06MTG002   FD             Ford   MTG           Mustang               06
# 2  FD08MTG003   FD             Ford   MTG           Mustang               08
#
#     Age    Miles  Miles / Year  Color  Driver  Warantee Miles  Covered?  \
# 0  17.0  40326.8           NaN  Black   Smith         50000.0       NaN
# 1  17.0  44974.8           NaN  White  McCall         50000.0       NaN
# 2  15.0  44946.5           NaN  Green    Lyon         50000.0       NaN
#
#    New Car ID  Ca    r   ID  Unnamed: 17  Miles Per Year  Miles Per year
# 0         NaN  FD  6.0  MTG          1.0     2372.164706     2372.164706
# 1         NaN  FD  6.0  MTG          2.0     2645.576471     2645.576471
# 2         NaN  FD  8.0  MTG          3.0     2996.433333     2996.433333

# %%
df_grouped = df.groupby(df['Model']).sorted_values('Color')
print(df_grouped)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 df_grouped = df.groupby(df['Model']).sorted_values('Color')
#       2 print(df_grouped)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sorted_values'

# %%
df.groupby(['Model']).mean()
# Out:
#                       Age         Miles  Miles / Year  Warantee Miles  \
# Model
# CAM             18.166667  72007.116667           NaN        100000.0
# CAR             19.750000  70472.575000           NaN         75000.0
# CIV             14.142857  39607.457143           NaN         75000.0
# CMR             11.333333  20725.166667           NaN        100000.0
# COR             15.250000  46267.500000           NaN        100000.0
# Chrystler             NaN           NaN           NaN             NaN
# ELA             10.750000  23449.175000           NaN        100000.0
# FCS             12.375000  30549.500000           NaN         75000.0
# Ford                  NaN           NaN           NaN             NaN
# General Motors        NaN           NaN           NaN             NaN
# Honda                 NaN           NaN           NaN             NaN
# Hyundai               NaN           NaN           NaN             NaN
# ...
